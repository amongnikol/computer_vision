# %%
from roboflow import Roboflow

import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv('ROBOFLOW_API_KEY')

rf = Roboflow(api_key=api_key)
project = rf.workspace("mongomow").project("golden-retriever-t7zpa")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Golden-Retriever-1 in yolov8:: 100%|██████████| 968/968 [00:00<00:00, 1402.04it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=Golden-Retriever-1/data.yaml epochs=100 imgsz=640 batch=8
# Out:
# ^C
# New https://pypi.org/project/ultralytics/8.3.163 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.162  Python-3.12.11 torch-2.7.1+cpu CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt show=true conf=0.5 source=test/download.jpg
# Out:
# Ultralytics 8.3.162  Python-3.12.11 torch-2.7.1+cpu CPU (AMD Ryzen 7 5700U with Radeon Graphics)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 c:\Users\akmal\Documents\repo\computer_vision\SimplifyingImageRecognition\with_yolo\test\download.jpg: 448x640 1 Golden retriever, 129.3ms
# Speed: 5.4ms preprocess, 129.3ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict
#  Learn more at https://docs.ultralytics.com/modes/predict
